# %%
import time
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras import backend as K
import activation_plot as aplt
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from tensorflow.keras.utils import to_categorical
# %matplotlib inline

#Prepare data
N=40000
L=4
X = L*np.random.rand(N,2) 
X[:,0] = X[:,0]-L/2
X[:,1] = X[:,1]-L/2

Y = np.zeros(N)

for i in range(N):
    if (X[i,0]-0.8)**2+(X[i,1]-0.8)**2<0.36:
        Y[i]=1
    else:
        Y[i]=0
        
plt.figure(figsize=(8, 8))
plt.scatter(X[:,0], X[:, 1], s=1, c=Y)
plt.show()

data = X
labels = to_categorical(Y)

# %%
hid_layer_units = [5,5]
model = aplt.prepare_model(hid_layer_units,n_category = len(labels[0]))
tf.keras.models.save_model(model,'model_initial')

# %%
model.fit(data, labels, epochs=10,verbose=1,batch_size=32)
# Out:
# Train on 40000 samples
# Epoch 1/10
# 40000/40000 - 2s - loss: 0.1971 - categorical_accuracy: 0.9247
# Epoch 2/10
# 40000/40000 - 2s - loss: 0.1180 - categorical_accuracy: 0.9314
# Epoch 3/10
# 40000/40000 - 2s - loss: 0.0800 - categorical_accuracy: 0.9646
# Epoch 4/10
# 40000/40000 - 2s - loss: 0.0484 - categorical_accuracy: 0.9858
# Epoch 5/10
# 40000/40000 - 2s - loss: 0.0324 - categorical_accuracy: 0.9919
# Epoch 6/10
# 40000/40000 - 1s - loss: 0.0247 - categorical_accuracy: 0.9934
# Epoch 7/10
# 40000/40000 - 1s - loss: 0.0204 - categorical_accuracy: 0.9946
# Epoch 8/10
# 40000/40000 - 1s - loss: 0.0176 - categorical_accuracy: 0.9948
# Epoch 9/10
# 40000/40000 - 1s - loss: 0.0157 - categorical_accuracy: 0.9959
# Epoch 10/10
# 40000/40000 - 1s - loss: 0.0143 - categorical_accuracy: 0.9958

# %%
X_test = aplt.data_grid(grid=200,square_len=2)
colors = aplt.get_color(X_test)

layer_output_functions=aplt.get_layer_output_functions(model)

activations = aplt.get_data_activation(X_test,layer_output_functions)
data_activation_color = aplt.get_data_color(activations,colors)

plt.figure(figsize=(9, 9))
plt.scatter(X_test[:, 0], X_test[:, 1], marker='o',s=4, c=data_activation_color)
#plt.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=Y_test, s=1,alpha = 0.8)
plt.grid()
plt.show()
plt.close()

# %%
model.fit(data, labels, epochs=20,verbose=1,batch_size=32)
# Out:
# Train on 40000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 2s 53us/sample - loss: 0.6906 - categorical_accuracy: 0.7947
# Epoch 2/20
# 40000/40000 [==============================] - 2s 51us/sample - loss: 0.4836 - categorical_accuracy: 0.8205
# Epoch 3/20
# 40000/40000 [==============================] - 2s 47us/sample - loss: 0.3845 - categorical_accuracy: 0.8416
# Epoch 4/20
# 40000/40000 [==============================] - 2s 52us/sample - loss: 0.3400 - categorical_accuracy: 0.8609
# Epoch 5/20
# 40000/40000 [==============================] - 2s 51us/sample - loss: 0.3129 - categorical_accuracy: 0.8678
# Epoch 6/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.2909 - categorical_accuracy: 0.8724
# Epoch 7/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.2726 - categorical_accuracy: 0.8747
# Epoch 8/20
# 40000/40000 [==============================] - 2s 51us/sample - loss: 0.2563 - categorical_accuracy: 0.8782
# Epoch 9/20
# 40000/40000 [==============================] - 2s 46us/sample - loss: 0.2428 - categorical_accuracy: 0.8834
# Epoch 10/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.2318 - categorical_accuracy: 0.8925
# Epoch 11/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.1867 - categorical_accuracy: 0.9330
# Epoch 12/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1199 - categorical_accuracy: 0.9664
# Epoch 13/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.0994 - categorical_accuracy: 0.9701
# Epoch 14/20
# 40000/40000 [==============================] - 2s 40us/sample - loss: 0.0903 - categorical_accuracy: 0.9711
# Epoch 15/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.0848 - categorical_accuracy: 0.9724
# Epoch 16/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.0805 - categorical_accuracy: 0.9737
# Epoch 17/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.0769 - categorical_accuracy: 0.9747
# Epoch 18/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.0731 - categorical_accuracy: 0.9760
# Epoch 19/20
# 40000/40000 [==============================] - 2s 38us/sample - loss: 0.0685 - categorical_accuracy: 0.9767
# Epoch 20/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.0653 - categorical_accuracy: 0.9779

# %%
A = np.transpose(A)

L = 4
x = np.linspace(-L,L,100)
Y = []
for i in range(hid_layer_units[0]):
    y = -A[i,0]/A[i,1]*x1+-b[i]/A[i,1]
    Y.append(y)

plt.figure(figsize=(9, 9))
for i in range(hid_layer_units[0]):
    plt.plot(x, Y[i], '-r', label='x1,y1')
plt.xlim(-L,L)
plt.ylim(-L,L)
plt.grid()
plt.show()

# %%
#model_copy = tf.keras.models.load_model('model_initial')
model_copy.layers[0].set_weights([model_copy.layers[0].get_weights()[0],0.1*model_copy.layers[0].get_weights()[1]])
model_copy.layers[0].get_weights()
# Out:
# [array([[-0.47130296,  0.33908898,  0.5546028 , -0.2515192 , -0.60918385,
#          -0.822586  ],
#         [ 0.45010585,  0.27299255, -0.08886546,  0.2528568 ,  0.36357468,
#          -0.43597585]], dtype=float32),
#  array([ 0.00446463, -0.00258882,  0.00108101, -0.00251932,  0.00203221,
#          0.00413989], dtype=float32)]

# %%
#model_copy = tf.keras.models.load_model('model_initial')

X_test = aplt.data_grid(grid=200,square_len=4)
colors = aplt.get_color(X_test)

layer_output_functions = aplt.get_layer_output_functions(model_copy)

activations = aplt.get_data_activation(X_test,layer_output_functions)
data_activation_color = aplt.get_data_color(activations,colors)

plt.figure(figsize=(9, 9))
plt.scatter(X_test[:, 0], X_test[:, 1], marker='o',s=4, c=data_activation_color)
#plt.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=Y_test, s=1,alpha = 0.8)
plt.grid()
plt.show()
plt.close()

# %%
model_copy.fit(data, labels, epochs=20,verbose=1,batch_size=32)
# Out:
# Train on 40000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 2s 40us/sample - loss: 0.6074 - categorical_accuracy: 0.8065
# Epoch 2/20
# 40000/40000 [==============================] - 2s 39us/sample - loss: 0.3844 - categorical_accuracy: 0.8204
# Epoch 3/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.3157 - categorical_accuracy: 0.8264
# Epoch 4/20
# 40000/40000 [==============================] - 2s 38us/sample - loss: 0.2713 - categorical_accuracy: 0.8565
# Epoch 5/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.2374 - categorical_accuracy: 0.8828
# Epoch 6/20
# 40000/40000 [==============================] - 2s 42us/sample - loss: 0.2119 - categorical_accuracy: 0.9071
# Epoch 7/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1928 - categorical_accuracy: 0.9222
# Epoch 8/20
# 40000/40000 [==============================] - 2s 44us/sample - loss: 0.1778 - categorical_accuracy: 0.9318
# Epoch 9/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1655 - categorical_accuracy: 0.9396
# Epoch 10/20
# 40000/40000 [==============================] - 2s 38us/sample - loss: 0.1556 - categorical_accuracy: 0.9438
# Epoch 11/20
# 40000/40000 [==============================] - 2s 41us/sample - loss: 0.1471 - categorical_accuracy: 0.9473
# Epoch 12/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.1399 - categorical_accuracy: 0.9503
# Epoch 13/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1334 - categorical_accuracy: 0.9529
# Epoch 14/20
# 40000/40000 [==============================] - 1s 37us/sample - loss: 0.1276 - categorical_accuracy: 0.9555
# Epoch 15/20
# 40000/40000 [==============================] - 2s 40us/sample - loss: 0.1223 - categorical_accuracy: 0.9568
# Epoch 16/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1171 - categorical_accuracy: 0.9592
# Epoch 17/20
# 40000/40000 [==============================] - 1s 36us/sample - loss: 0.1127 - categorical_accuracy: 0.9601
# Epoch 18/20
# 40000/40000 [==============================] - 2s 42us/sample - loss: 0.1088 - categorical_accuracy: 0.9622
# Epoch 19/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.1053 - categorical_accuracy: 0.9631
# Epoch 20/20
# 40000/40000 [==============================] - 2s 45us/sample - loss: 0.1022 - categorical_accuracy: 0.9640

# %% [markdown]
# # Add BN

# %%
# import BatchNormalization
from tensorflow.keras.layers import BatchNormalization

# instantiate model
model_bn = Sequential()

# we can think of this chunk as the input layer
model_bn.add(BatchNormalization(input_shape=(2,)))
model_bn.add(Dense(hid_layer_units[0], input_dim=2, bias_initializer='random_uniform'))
model_bn.add(BatchNormalization())
model_bn.add(Activation('relu'))


# we can think of this chunk as the hidden layer    
model_bn.add(Dense(hid_layer_units[1], bias_initializer='random_uniform'))
model_bn.add(BatchNormalization())
model_bn.add(Activation('relu'))

# we can think of this chunk as the output layer
model_bn.add(Dense(4, bias_initializer='random_uniform'))
model_bn.add(BatchNormalization())
model_bn.add(Activation('softmax'))

# setting up the optimization of our weights 
model_bn.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.categorical_crossentropy,
                  metrics=[tf.keras.metrics.categorical_accuracy])

model_bn.fit(data, labels, epochs=10,verbose=1,batch_size=32)
# Out:
# Train on 40000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 3s 69us/sample - loss: 0.5521 - categorical_accuracy: 0.8076
# Epoch 2/10
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.2778 - categorical_accuracy: 0.8623
# Epoch 3/10
# 40000/40000 [==============================] - 2s 54us/sample - loss: 0.1636 - categorical_accuracy: 0.9291
# Epoch 4/10
# 40000/40000 [==============================] - 2s 59us/sample - loss: 0.1347 - categorical_accuracy: 0.9405
# Epoch 5/10
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.1184 - categorical_accuracy: 0.9495
# Epoch 6/10
# 40000/40000 [==============================] - 3s 68us/sample - loss: 0.1063 - categorical_accuracy: 0.9546
# Epoch 7/10
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.0945 - categorical_accuracy: 0.9611
# Epoch 8/10
# 40000/40000 [==============================] - 3s 67us/sample - loss: 0.0857 - categorical_accuracy: 0.9665
# Epoch 9/10
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.0786 - categorical_accuracy: 0.9689
# Epoch 10/10
# 40000/40000 [==============================] - 3s 65us/sample - loss: 0.0752 - categorical_accuracy: 0.9683

# %%
X_test = aplt.data_grid(grid=200,square_len=4)
colors = aplt.get_color(X_test)

layer_output_functions = []
layer_output_functions.append(K.function(model_bn.layers[0].input,model_bn.layers[3].output))
layer_output_functions.append(K.function(model_bn.layers[0].input,model_bn.layers[6].output))

activations = aplt.get_data_activation(X_test,layer_output_functions)
data_activation_color = aplt.get_data_color(activations,colors)

plt.figure(figsize=(9, 9))
plt.scatter(X_test[:, 0], X_test[:, 1], marker='o',s=4, c=data_activation_color)
#plt.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=Y_test, s=1,alpha = 0.8)
plt.grid()
plt.show()
plt.close()

# %%
model_bn.fit(data, labels, epochs=20,verbose=1,batch_size=32)
# Out:
# Train on 40000 samples
# Epoch 1/20
# 40000/40000 [==============================] - 3s 63us/sample - loss: 0.5439 - categorical_accuracy: 0.8063
# Epoch 2/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.2338 - categorical_accuracy: 0.8856
# Epoch 3/20
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.1542 - categorical_accuracy: 0.9371
# Epoch 4/20
# 40000/40000 [==============================] - 3s 63us/sample - loss: 0.1190 - categorical_accuracy: 0.9548
# Epoch 5/20
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.1004 - categorical_accuracy: 0.9611
# Epoch 6/20
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.0888 - categorical_accuracy: 0.9660
# Epoch 7/20
# 40000/40000 [==============================] - 3s 64us/sample - loss: 0.0816 - categorical_accuracy: 0.9679
# Epoch 8/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0757 - categorical_accuracy: 0.9696
# Epoch 9/20
# 40000/40000 [==============================] - 2s 61us/sample - loss: 0.0722 - categorical_accuracy: 0.9714
# Epoch 10/20
# 40000/40000 [==============================] - 2s 61us/sample - loss: 0.0693 - categorical_accuracy: 0.9723
# Epoch 11/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0669 - categorical_accuracy: 0.9725
# Epoch 12/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0644 - categorical_accuracy: 0.9732
# Epoch 13/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0626 - categorical_accuracy: 0.9739
# Epoch 14/20
# 40000/40000 [==============================] - 2s 53us/sample - loss: 0.0612 - categorical_accuracy: 0.9741
# Epoch 15/20
# 40000/40000 [==============================] - 2s 61us/sample - loss: 0.0593 - categorical_accuracy: 0.9747
# Epoch 16/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0574 - categorical_accuracy: 0.9761
# Epoch 17/20
# 40000/40000 [==============================] - 2s 58us/sample - loss: 0.0545 - categorical_accuracy: 0.9778
# Epoch 18/20
# 40000/40000 [==============================] - 2s 62us/sample - loss: 0.0516 - categorical_accuracy: 0.9791
# Epoch 19/20
# 40000/40000 [==============================] - 3s 64us/sample - loss: 0.0511 - categorical_accuracy: 0.9789
# Epoch 20/20
# 40000/40000 [==============================] - 2s 60us/sample - loss: 0.0499 - categorical_accuracy: 0.9798

# %%
#test
import numpy as np

X_test = aplt.data_grid(200,2)
Y_test = model_bn.predict(X_test)
Y_test = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8, 8))
plt.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=Y_test, s=1,alpha=1)
plt.show()
plt.close()

# %%
model_bn.layers[]
# Out:
# [<tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f09207dca58>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f09207dce80>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f09122a45c0>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f09417ca080>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f09352b6240>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f09352b6860>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f09424c10b8>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f093fea0898>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f093fea0d30>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f09413d10f0>]
