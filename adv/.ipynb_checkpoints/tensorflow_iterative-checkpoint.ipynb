# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.callbacks import TensorBoard

import multiprocessing
from multiprocessing import Pool
from functools import partial
# %matplotlib inline

def clear_line():
    print(' '*80,end='\r')
    
#function to get activation of input data into a list
def get_activation(data, get_layer_output_functions): 
    layer_output = []
    for f in get_layer_output_functions[:-1]:
        layer_output.append(f(data.reshape(1,2))[0])

    for i in range(len(layer_output)):
        #layer_nonzero_index = np.flatnonzero(layer_output[i])
        layer_output[i][np.flatnonzero(layer_output[i])] = 1
        layer_output[i] = layer_output[i].astype(int)
        
    act_list = layer_output
    return act_list

#assign a different color to each different activation,use color index
def assign_color(hid_layer_units,activations,act_index):
    color_index = 0
    for i in range(len(hid_layer_units)):
        binary = ''.join(str(e) for e in activations[act_index][i].astype(int))
        color_index+=int(binary,2)
    return color_index

def prepare_model(hid_layer_units):
    model = tf.keras.Sequential()
    for i in range(len(hid_layer_units)):
        if i == 0:
            model.add(Dense(hid_layer_units[i], input_shape=(2,), activation='relu',bias_initializer='random_uniform'))
        else:
            model.add(Dense(hid_layer_units[i], activation='relu',bias_initializer='random_uniform'))
    model.add(Dense(2, activation='softmax',bias_initializer='random_uniform'))
    # Configure a model for categorical classification.
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.categorical_crossentropy,
                  metrics=[tf.keras.metrics.categorical_accuracy])
    return model

def data_grid(grid, square_len):
    k = square_len
    x = np.linspace(-k,k,grid+1)
    y = np.linspace(-k,k,grid+1) 

    xv,yv = np.meshgrid( x , y )
    data = np.array([xv.flatten(),yv.flatten()])
    data = data.transpose()
    return data

def get_color(data):
    interval = int(np.ceil(255/len(data)**(1/3.0)))
    R = range(0,255,interval)
    G = range(0,255,interval)
    B = range(0,255,interval)
    rv,gv,bv = np.meshgrid(R,G,B)
    colors = np.array([rv.flatten(),gv.flatten(),bv.flatten()]).transpose()
    np.random.shuffle(colors)
    return colors

def draw_activation_and_prediction(hid_layer_units,num_epoch, colors, plot_style, X_test, model,pool):
    pool = Pool(8)
    for epoch_i in range(num_epoch):
        epoch_info = "epoch:{0} ".format(epoch_i)
        print(epoch_info, end="\r")
        #loop for all data points to get activations
        i_data = 0
        activations = []

        for test_data in X_test:
            act_progress = "get activation progress:{0}%".format(round((i_data + 1) * 100 / len(X_test)))
            print(epoch_info+act_progress,end='\r')
            activations.append(get_activation(test_data,get_layer_output_functions))
            i_data = i_data + 1
        clear_line()

        f = partial(assign_color,hid_layer_units,activations)
        i_color=0
        data_activation_color=[]
        for y in pool.map(f, range(len(activations))):
            i_color+=1
            color_progress = "get data color progress:{0}%".format(round((i_color + 1) * 100 / len(activations)))
            print(epoch_info+color_progress,end='\r')
            data_activation_color.append(y)
        clear_line()

        data_activation_color = np.asarray(data_activation_color)
        data_color_cluster = np.unique(data_activation_color)
        for color_i in range(len(data_activation_color)):
            [data_activation_color[color_i]] = np.where(data_color_cluster == data_activation_color[color_i])[0]
        if plot_style == style[1]:
            data_activation_color = colors[data_activation_color]/255

        plt.figure(figsize=(10, 10))
        plt.scatter(X_test[:, 0], X_test[:, 1], marker='o',s=4, c=data_activation_color, linewidths=2,cmap = 'gray')
        plt.title('epoch'+str(format(epoch_i,'0>3'))+'_'+model_name+'_activation',fontsize=20)
        plt.savefig(directory+'/'+'epoch'+str(format(epoch_i,'0>3'))+'_'+model_name+'_activation')
        plt.close()

        Y_test = model.predict(X_test)
        plt.figure(figsize=(10, 10))
        intensity = [np.append(k*np.array([255,255]),0)/255.0 for k in Y_test]
        plt.scatter(X_test[:, 0], X_test[:, 1], marker='o',s=3, c=intensity, linewidths=1, label='Class 1')
        plt.title('epoch'+str(format(epoch_i,'0>3'))+'_'+model_name+'_predictProbility',fontsize=20)
        plt.savefig(directory+'/'+'epoch'+str(format(epoch_i,'0>3'))+'_'+model_name+'_predictProbility')    
        plt.close()

        step = epoch_i+1
        history = model.fit(data, labels, epochs=1,verbose=0,steps_per_epoch=step,batch_size=int(N/800))
        train_info = epoch_info+str(history.history)
        print(train_info, end='\n')

# %% [markdown]
# ## Prepare Data

# %%
#Prepare data
N=40000
L=3
X = L*np.random.rand(N,2) 
X[:,0] = X[:,0]-L/2
X[:,1] = X[:,1]-L/2

Y = np.zeros([N,2])

for i in range(N):
    if (X[i,0])**2+(X[i,1])**2<0.64:
        Y[i,0]=1
    else:
        Y[i,1]=1

zero_class = np.where(Y[:, 0])
one_class = np.where(Y[:, 1])

# plt.figure(figsize=(8, 8))
# plt.scatter(X[zero_class, 0], X[zero_class, 1], s=1, facecolors='b', linewidths=1, label='Class 1')
# plt.scatter(X[one_class, 0], X[one_class, 1], s=1, facecolors='r', linewidths=1, label='Class 2')
# plt.show()

data = X
labels = Y

# %%
import os
from tensorflow.keras import backend as K

style = ['intensity_plot','color_plot']
plot_style = style[1]

first_layer = [3,4,5,6,7]
second_layer = [3,4,5,6,7]

num_epoch = 100
X_test = data_grid(grid=200,square_len=2)
colors = get_color(X_test)
pool = Pool(8)

for i in range(len(first_layer)):
    for j in range(len(second_layer)):
        print('hid_layer: [%i , %i]'%(first_layer[i],second_layer[j]))
        print('progress :', (i+j)/(len(first_layer)+len(second_layer)))
        hid_layer_units = [first_layer[i], second_layer[j]]
        model = prepare_model(hid_layer_units)
        
        model_name = '_'.join(str(e) for e in hid_layer_units)+'_2'+'_'+plot_style
        directory = 'iterasive_result/'+'model_'+model_name
        if not os.path.exists(directory):
            os.makedirs(directory)
        #model.save(directory+'/'+'initial'+model_name+'_model.h5') 
        
        get_layer_output_functions = []
        for layer_i in range(len(model.layers)):
            get_layer_output_functions.append(K.function(model.layers[0].input,model.layers[layer_i].output))
                     
        draw_activation_and_prediction(hid_layer_units,num_epoch, colors, plot_style, X_test, model,pool)

pool.close()
pool.join()
# Out:
# hid_layer: [3 , 3]
# progress : 0.0
# WARNING: Logging before flag parsing goes to stderr.
# W0819 04:48:07.957653 140111533270848 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# epoch:0 {'loss': [1.2355369329452515], 'categorical_accuracy': [0.2199]}
# epoch:1 {'loss': [1.2278708219528198], 'categorical_accuracy': [0.2199]}
# epoch:2 {'loss': [1.215207576751709], 'categorical_accuracy': [0.2199]}
# epoch:3 {'loss': [1.1977131962776184], 'categorical_accuracy': [0.21999376]}
# epoch:4 {'loss': [1.17564857006073], 'categorical_accuracy': [0.42267]}
# epoch:5 {'loss': [1.1495344241460164], 'categorical_accuracy': [0.475075]}
# epoch:6 {'loss': [1.1199324471609933], 'categorical_accuracy': [0.47628215]}
# epoch:7 {'loss': [1.087153136730194], 'categorical_accuracy': [0.4778219]}
# epoch:8 {'loss': [1.051785151163737], 'categorical_accuracy': [0.47993332]}
# epoch:9 {'loss': [1.0143580079078673], 'categorical_accuracy': [0.4848975]}
# epoch:10 {'loss': [0.9753808704289523], 'categorical_accuracy': [0.49320683]}
# epoch:11 {'loss': [0.9355943401654562], 'categorical_accuracy': [0.5037729]}
# epoch:12 {'loss': [0.8956886346523578], 'categorical_accuracy': [0.5157077]}
# epoch:13 {'loss': [0.8562751412391663], 'categorical_accuracy': [0.5247322]}
# epoch:14 {'loss': [0.8178890347480774], 'categorical_accuracy': [0.53168666]}
# epoch:15 {'loss': [0.7809575721621513], 'categorical_accuracy': [0.5398266]}
# epoch:16 {'loss': [0.7458181661718032], 'categorical_accuracy': [0.55190295]}
# epoch:17 {'loss': [0.7126806941297319], 'categorical_accuracy': [0.5697347]}
# epoch:18 {'loss': [0.6817758585277357], 'categorical_accuracy': [0.59821844]}
# epoch:23 {'loss': [0.5572558417916298], 'categorical_accuracy': [0.7801]}
# epoch:24 get activation progress:35%
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# epoch:24 get data color progress:3%
# epoch:24 get data color progress:7%
# epoch:24 get data color progress:11%
# epoch:24 get data color progress:15%
# epoch:24 get data color progress:19%
# epoch:24 get data color progress:23%
# epoch:24 get data color progress:28%
# epoch:24 get data color progress:32%
# epoch:24 get data color progress:36%
# epoch:24 get data color progress:41%
# epoch:24 get data color progress:45%
# epoch:24 get data color progress:49%
# epoch:24 get data color progress:53%
# epoch:24 get data color progress:58%
# epoch:24 get data color progress:62%
# epoch:24 get data color progress:66%
# epoch:24 get data color progress:70%
# epoch:24 get data color progress:74%
# epoch:24 get data color progress:78%
# epoch:24 get data color progress:82%
# epoch:24 get data color progress:87%
# epoch:24 get data color progress:91%
# epoch:24 get data color progress:94%
# epoch:24 get data color progress:98%
# epoch:24 get data color progress:100%
# epoch:24 {'loss': [0.538624975681305], 'categorical_accuracy': [0.7801]}
# epoch:25 get activation progress:2%
# epoch:25 get activation progress:2%
# epoch:25 get activation progress:3%
# epoch:25 get activation progress:4%
# epoch:25 get activation progress:5%
# epoch:25 get activation progress:5%
# epoch:25 get activation progress:6%
# epoch:25 get activation progress:7%
# epoch:25 get activation progress:8%
# epoch:25 get activation progress:8%
# epoch:25 get activation progress:9%
# epoch:25 get activation progress:10%
# epoch:25 get activation progress:10%
# epoch:25 get activation progress:11%
# epoch:25 get activation progress:12%
# epoch:25 get activation progress:13%
# epoch:25 get activation progress:13%
# epoch:25 get activation progress:14%
# epoch:25 get activation progress:15%
# epoch:25 get activation progress:16%
# epoch:25 get activation progress:16%
# epoch:25 get activation progress:17%
# epoch:25 get activation progress:18%
# epoch:25 get activation progress:19%
# epoch:25 {'loss': [0.5239500884826367], 'categorical_accuracy': [0.7801]}
# epoch:26 {'loss': [0.5137722558445401], 'categorical_accuracy': [0.7801]}
# epoch:27 {'loss': [0.5070336099181857], 'categorical_accuracy': [0.7801]}
# epoch:28 {'loss': [0.5025432438685976], 'categorical_accuracy': [0.7801]}
# epoch:29 {'loss': [0.4994001676638921], 'categorical_accuracy': [0.7801]}
# epoch:30 {'loss': [0.49698655451497725], 'categorical_accuracy': [0.7801]}
# epoch:31 {'loss': [0.49491189140826464], 'categorical_accuracy': [0.7801]}
# epoch:32 {'loss': [0.4929491633718664], 'categorical_accuracy': [0.7801]}

# %%
# for i in range(100):
#     step = i+1
#     model.fit(data, labels, epochs=1,steps_per_epoch=step,batch_size=int(N/800),callbacks=[tensorboard])

# %%
#test
import numpy as np

X_test = get_data_grid(200,0.5)
#np.random.shuffle(X_test)

Y_test = model.predict(X_test)
Y_test = np.rint(Y_test)

zero_class_test = np.where(Y_test[:, 0])
one_class_test = np.where(Y_test[:, 1])

plt.figure(figsize=(8, 8))
plt.scatter(X_test[zero_class_test, 0], X_test[zero_class_test, 1], marker='o',s=3, facecolors='r', linewidths=1, label='Class 1')
plt.scatter(X_test[one_class_test, 0], X_test[one_class_test, 1], marker='o', s=1, facecolors='b', linewidths=1, label='Class 2')
plt.show()
plt.savefig(directory+'/'+'test')
plt.close()

# %%
progress = 0
plt.figure(figsize=(12, 12))
for k in range(len(cluster_index)):
    progress += 1
    #print("Progress:{0}%".format(round((progress + 1) * 100 / len(cluster_index))), end="\r")
    plt.scatter(X_test[cluster_index[k], 0], X_test[cluster_index[k], 1], marker='o',s=4, color=colors[data_activation_color[cluster_index[k]][0]]/255.0, linewidths=2)
plt.margins(x=0.1, y=0.1)
plt.show()
plt.savefig('activation')

# %%
get_layer_output_functions
# Out:
# [<tensorflow.python.keras.backend.EagerExecutionFunction at 0x7feea879c748>,
#  <tensorflow.python.keras.backend.EagerExecutionFunction at 0x7feea879c4e0>,
#  <tensorflow.python.keras.backend.EagerExecutionFunction at 0x7fedb47a9b70>,
#  <tensorflow.python.keras.backend.EagerExecutionFunction at 0x7feea854b048>,
#  <tensorflow.python.keras.backend.EagerExecutionFunction at 0x7feea854b400>,
#  <tensorflow.python.keras.backend.EagerExecutionFunction at 0x7fec5d3f6b00>]
