# %% [markdown]
# ## Prepare Data

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from tensorflow.keras.utils import to_categorical
import numpy as np
import tensorflow as tf
# %matplotlib inline

random_state=7
X, Y = make_blobs(n_samples=10000,n_features=2, cluster_std=0.3,centers=4,center_box=(-2.0, 2.0),random_state=7)

plt.figure(figsize=(8, 8))
plt.scatter(X[:, 0], X[:, 1], c=Y, s=1)
plt.show()

data = X
labels = to_categorical(Y)

# %%
import os
import activation_plot as aplt

first_layer = [4,8,10,20]
second_layer = [4,8,10,20]

num_epoch = 100
#batch_size = 32
X_test = aplt.data_grid(grid=200,square_len=2)
colors = aplt.get_color(X_test)

for i in range(len(first_layer)):
    for j in range(len(second_layer)):
        hid_layer_units = [first_layer[i], second_layer[j]]
        print('hid_layer: '+str(hid_layer_units))
        print('progress :', (i+j)/(len(first_layer)+len(second_layer)))

        model = aplt.prepare_model(hid_layer_units,n_category = len(labels[0]))

        net_name = '_'.join(str(e) for e in hid_layer_units)+'_2'
        model_name = 'model_'+net_name
        result_dir = 'iterasive_result/'+model_name
        if not os.path.exists(result_dir):
            os.makedirs(result_dir)
        model_data_labels = [model, data, labels]
        aplt.get_activation_prediction_transition(result_dir,num_epoch,X_test,model_data_labels)
# Out:
# hid_layer: [4, 4]
# progress : 0.0
# WARNING: Logging before flag parsing goes to stderr.
# W0826 07:55:53.754415 140629566056256 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# epoch 1: {'loss': [1.404971957206726], 'categorical_accuracy': [0.2584]}
# epoch 2: {'loss': [1.401118814945221], 'categorical_accuracy': [0.25655]}
# epoch 3: {'loss': [1.3947563568751018], 'categorical_accuracy': [0.2516]}
# epoch 4: {'loss': [1.3859644532203674], 'categorical_accuracy': [0.25]}
# epoch 5: {'loss': [1.3747988939285278], 'categorical_accuracy': [0.24996]}
# epoch 6: {'loss': [1.3612842758496602], 'categorical_accuracy': [0.2499]}
# epoch 7: {'loss': [1.3455952916826521], 'categorical_accuracy': [0.2499]}
# epoch 8: {'loss': [1.3288911134004593], 'categorical_accuracy': [0.2498125]}
# epoch 9: {'loss': [1.310960637198554], 'categorical_accuracy': [0.25002223]}
# epoch 10: {'loss': [1.2902075171470642], 'categorical_accuracy': [0.2502]}
# epoch 11: {'loss': [1.275435751134699], 'categorical_accuracy': [0.4094273]}
# epoch 12: {'loss': [1.2649330695470173], 'categorical_accuracy': [0.5008917]}
# epoch 13: {'loss': [1.2521948906091542], 'categorical_accuracy': [0.5013308]}
# epoch 14: {'loss': [1.2372507452964783], 'categorical_accuracy': [0.50202143]}
# epoch 15: {'loss': [1.219990356763204], 'categorical_accuracy': [0.5035267]}
# epoch 16: {'loss': [1.200313240289688], 'categorical_accuracy': [0.50578123]}
# epoch 17: {'loss': [1.178261637687683], 'categorical_accuracy': [0.50905293]}
# epoch 18: {'loss': [1.1540443632337782], 'categorical_accuracy': [0.5162944]}
# epoch 19: {'loss': [1.1278851408707469], 'categorical_accuracy': [0.52647895]}
# epoch 20: {'loss': [1.1001068890094756], 'categorical_accuracy': [0.53707]}
# epoch 21: {'loss': [1.0712044011978876], 'categorical_accuracy': [0.55020475]}
# epoch 22: {'loss': [1.0416855703700671], 'categorical_accuracy': [0.56486815]}
# epoch 23: {'loss': [1.0119303257569023], 'categorical_accuracy': [0.58736956]}
# epoch 24: {'loss': [0.9821011150876681], 'categorical_accuracy': [0.6281625]}
# epoch 25: {'loss': [0.9520965623855591], 'categorical_accuracy': [0.66754]}
# epoch 26: {'loss': [0.9215203340236957], 'categorical_accuracy': [0.72126156]}
# epoch 27: {'loss': [0.8897041943338182], 'categorical_accuracy': [0.68608886]}
# epoch 28: {'loss': [0.8557469908680234], 'categorical_accuracy': [0.70669645]}
# epoch 29: {'loss': [0.8186359693264139], 'categorical_accuracy': [0.7347793]}
# epoch 30: {'loss': [0.7775506953398387], 'categorical_accuracy': [0.74352664]}
# epoch 31: {'loss': [0.7323207047677809], 'categorical_accuracy': [0.7465903]}
# epoch 32: {'loss': [0.6841711215674877], 'categorical_accuracy': [0.74833125]}
# epoch 33: {'loss': [0.6360846848198862], 'categorical_accuracy': [0.74870604]}
# epoch 34: {'loss': [0.591890449033064], 'categorical_accuracy': [0.74847645]}
# epoch 35: {'loss': [0.5542387076786586], 'categorical_accuracy': [0.74833715]}
# epoch 36: {'loss': [0.5234936823447546], 'categorical_accuracy': [0.74808335]}
# epoch 37: {'loss': [0.4984415423225712], 'categorical_accuracy': [0.748]}
# epoch 38: {'loss': [0.4774275727962193], 'categorical_accuracy': [0.7479079]}
# epoch 39: {'loss': [0.45898802463824934], 'categorical_accuracy': [0.7478718]}
# epoch 40: {'loss': [0.4420247323811054], 'categorical_accuracy': [0.7478]}
# epoch 41: {'loss': [0.42582528184099894], 'categorical_accuracy': [0.74791217]}
# epoch 42: {'loss': [0.40998980970609755], 'categorical_accuracy': [0.7481809]}
# epoch 43: {'loss': [0.39428995792255844], 'categorical_accuracy': [0.94313025]}
# epoch 44: {'loss': [0.3786206468939781], 'categorical_accuracy': [0.9882182]}
# epoch 45: {'loss': [0.36293536557091605], 'categorical_accuracy': [0.9888644]}
# epoch 46: {'loss': [0.34720891066219495], 'categorical_accuracy': [0.9890044]}

# %% [markdown]
# # plot data

# %%
import activation_plot as aplt
import os
X_test = aplt.data_grid(grid=200,square_len=2)
colors = aplt.get_color(X_test)

first_layer = [4,8,10,20]
second_layer = [4,8,10,20]

if __name__ == '__main__':
    data_path_list = []
    for i in first_layer:
        for j in second_layer:
            path = 'iterasive_result/model_'+str(i)+'_'+str(j)+'_2'
            if os.path.exists(path):
                data_path_list.append(path)
                
    progress = 0
    for data_path in data_path_list:
        print('progress : {0}%'.format(int(100*progress/len(data_path_list))))
        progress += 1
        aplt.plot_data(data_path,X_test,colors)
# Out:
# progress : 0%
# Process iterasive_result/model_4_4_2
# plot progress:3%

# %%
# hid_layer_units = [30,30]
# model = prepare_model(hid_layer_units, 4)
# for i in range(100):
#     step = i+1
#     model.fit(data, labels, epochs=1,steps_per_epoch=step,batch_size=32)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0821 00:55:12.663591 139688749041472 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 1 samples
# 1/1 [==============================] - 0s 117ms/step - loss: 1.4827 - categorical_accuracy: 0.2480
# Train on 2 samples
# 2/2 [==============================] - 0s 6ms/step - loss: 1.4478 - categorical_accuracy: 0.2480
# Train on 3 samples
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3911 - categorical_accuracy: 0.2480
# Train on 4 samples
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3147 - categorical_accuracy: 0.2476
# Train on 5 samples
# 5/5 [==============================] - 0s 5ms/step - loss: 1.2215 - categorical_accuracy: 0.3598
# Train on 6 samples
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1163 - categorical_accuracy: 0.7712
# Train on 7 samples
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0032 - categorical_accuracy: 0.9274
# Train on 8 samples
# 8/8 [==============================] - 0s 5ms/step - loss: 0.8855 - categorical_accuracy: 0.9501
# Train on 9 samples
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7695 - categorical_accuracy: 0.9410
# Train on 10 samples
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6537 - categorical_accuracy: 0.9411
# Train on 11 samples
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5392 - categorical_accuracy: 0.9565
# Train on 12 samples
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4320 - categorical_accuracy: 0.9685
# Train on 13 samples
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3378 - categorical_accuracy: 0.9770
# Train on 14 samples
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2615 - categorical_accuracy: 0.9821
# Train on 15 samples
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2023 - categorical_accuracy: 0.9850
# Train on 16 samples
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1574 - categorical_accuracy: 0.9875
# Train on 17 samples
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1238 - categorical_accuracy: 0.9896
# Train on 18 samples
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0988 - categorical_accuracy: 0.9911
# Train on 19 samples
# 19/19 [==============================] - 0s 5ms/step - loss: 0.0802 - categorical_accuracy: 0.9921
# Train on 20 samples
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0662 - categorical_accuracy: 0.9925
# Train on 21 samples
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0554 - categorical_accuracy: 0.9925
# Train on 22 samples
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0470 - categorical_accuracy: 0.9935
# Train on 23 samples
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0403 - categorical_accuracy: 0.9937
# Train on 24 samples
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0349 - categorical_accuracy: 0.9940
# Train on 25 samples
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0304 - categorical_accuracy: 0.9949
# Train on 26 samples
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0268 - categorical_accuracy: 0.9951
# Train on 27 samples
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0238 - categorical_accuracy: 0.9955
# Train on 28 samples
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0214 - categorical_accuracy: 0.9959
# Train on 29 samples
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0194 - categorical_accuracy: 0.9964
# Train on 30 samples
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0177 - categorical_accuracy: 0.9965
# Train on 31 samples
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0163 - categorical_accuracy: 0.9969
# Train on 32 samples
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0151 - categorical_accuracy: 0.9970
# Train on 33 samples
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0141 - categorical_accuracy: 0.9970
# Train on 34 samples
# 34/34 [==============================] - 0s 6ms/step - loss: 0.0133 - categorical_accuracy: 0.9970
# Train on 35 samples
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0126 - categorical_accuracy: 0.9970
# Train on 36 samples
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0119 - categorical_accuracy: 0.9970
# Train on 37 samples
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0114 - categorical_accuracy: 0.9970
# Train on 38 samples
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0110 - categorical_accuracy: 0.9970
# Train on 39 samples
# 39/39 [==============================] - 0s 5ms/step - loss: 0.0106 - categorical_accuracy: 0.9970
# Train on 40 samples
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0102 - categorical_accuracy: 0.9970
# Train on 41 samples
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0099 - categorical_accuracy: 0.9971
# Train on 42 samples
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0096 - categorical_accuracy: 0.9980
# Train on 43 samples
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0094 - categorical_accuracy: 0.9980
# Train on 44 samples
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0091 - categorical_accuracy: 0.9980
# Train on 45 samples
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0090 - categorical_accuracy: 0.9977
# Train on 46 samples
# 46/46 [==============================] - 0s 5ms/step - loss: 0.0088 - categorical_accuracy: 0.9975
# Train on 47 samples
# 47/47 [==============================] - 0s 5ms/step - loss: 0.0086 - categorical_accuracy: 0.9975
# Train on 48 samples
# 48/48 [==============================] - 0s 5ms/step - loss: 0.0085 - categorical_accuracy: 0.9975
# Train on 49 samples
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0084 - categorical_accuracy: 0.9975
# Train on 50 samples
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0083 - categorical_accuracy: 0.9975
# Train on 51 samples
# 51/51 [==============================] - 0s 5ms/step - loss: 0.0082 - categorical_accuracy: 0.9975
# Train on 52 samples
# 52/52 [==============================] - 0s 5ms/step - loss: 0.0081 - categorical_accuracy: 0.9975
# Train on 53 samples
# 53/53 [==============================] - 0s 5ms/step - loss: 0.0079 - categorical_accuracy: 0.9978
# Train on 54 samples
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0079 - categorical_accuracy: 0.9980
# Train on 55 samples
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0078 - categorical_accuracy: 0.9980
# Train on 56 samples
# 56/56 [==============================] - 0s 5ms/step - loss: 0.0077 - categorical_accuracy: 0.9980
# Train on 57 samples
# 57/57 [==============================] - 0s 5ms/step - loss: 0.0076 - categorical_accuracy: 0.9980
# Train on 58 samples
# 58/58 [==============================] - 0s 5ms/step - loss: 0.0076 - categorical_accuracy: 0.9980
# Train on 59 samples
# 59/59 [==============================] - 0s 5ms/step - loss: 0.0075 - categorical_accuracy: 0.9980
# Train on 60 samples
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0075 - categorical_accuracy: 0.9980
# Train on 61 samples
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0074 - categorical_accuracy: 0.9980
# Train on 62 samples
# 62/62 [==============================] - 0s 4ms/step - loss: 0.0074 - categorical_accuracy: 0.9980
# Train on 63 samples
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0074 - categorical_accuracy: 0.9980
# Train on 64 samples
# 64/64 [==============================] - 0s 5ms/step - loss: 0.0073 - categorical_accuracy: 0.9980
# Train on 65 samples
# 65/65 [==============================] - 0s 5ms/step - loss: 0.0073 - categorical_accuracy: 0.9980
# Train on 66 samples
# 66/66 [==============================] - 0s 5ms/step - loss: 0.0072 - categorical_accuracy: 0.9980
# Train on 67 samples
# 67/67 [==============================] - 0s 5ms/step - loss: 0.0072 - categorical_accuracy: 0.9980
# Train on 68 samples
# 68/68 [==============================] - 0s 5ms/step - loss: 0.0072 - categorical_accuracy: 0.9980
# Train on 69 samples
# 69/69 [==============================] - 0s 5ms/step - loss: 0.0072 - categorical_accuracy: 0.9980
# Train on 70 samples
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0071 - categorical_accuracy: 0.9980
# Train on 71 samples
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0071 - categorical_accuracy: 0.9980
# Train on 72 samples
# 72/72 [==============================] - 0s 5ms/step - loss: 0.0071 - categorical_accuracy: 0.9980
# Train on 73 samples
# 73/73 [==============================] - 0s 6ms/step - loss: 0.0070 - categorical_accuracy: 0.9980
# Train on 74 samples
# 74/74 [==============================] - 0s 5ms/step - loss: 0.0070 - categorical_accuracy: 0.9980
# Train on 75 samples
# 75/75 [==============================] - 0s 5ms/step - loss: 0.0070 - categorical_accuracy: 0.9980
# Train on 76 samples
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0069 - categorical_accuracy: 0.9980
# Train on 77 samples
# 77/77 [==============================] - 0s 5ms/step - loss: 0.0069 - categorical_accuracy: 0.9980
# Train on 78 samples
# 78/78 [==============================] - 0s 5ms/step - loss: 0.0069 - categorical_accuracy: 0.9980
# Train on 79 samples
# 79/79 [==============================] - 0s 5ms/step - loss: 0.0068 - categorical_accuracy: 0.9980
# Train on 80 samples
# 80/80 [==============================] - 0s 5ms/step - loss: 0.0068 - categorical_accuracy: 0.9980
# Train on 81 samples
# 81/81 [==============================] - 0s 6ms/step - loss: 0.0068 - categorical_accuracy: 0.9980
# Train on 82 samples
# 82/82 [==============================] - 0s 6ms/step - loss: 0.0067 - categorical_accuracy: 0.9980
# Train on 83 samples
# 83/83 [==============================] - 0s 5ms/step - loss: 0.0067 - categorical_accuracy: 0.9980
# Train on 84 samples
# 84/84 [==============================] - 0s 6ms/step - loss: 0.0067 - categorical_accuracy: 0.9980
# Train on 85 samples
# 85/85 [==============================] - 0s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.9977
# Train on 86 samples
# 86/86 [==============================] - 0s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.9975
# Train on 87 samples
# 87/87 [==============================] - 0s 6ms/step - loss: 0.0066 - categorical_accuracy: 0.9976
# Train on 88 samples
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.9979
# Train on 89 samples
# 89/89 [==============================] - 0s 5ms/step - loss: 0.0066 - categorical_accuracy: 0.9980
# Train on 90 samples
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 91 samples
# 91/91 [==============================] - 0s 5ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 92 samples
# 92/92 [==============================] - 1s 6ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 93 samples
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 94 samples
# 94/94 [==============================] - 0s 5ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 95 samples
# 95/95 [==============================] - 0s 5ms/step - loss: 0.0065 - categorical_accuracy: 0.9980
# Train on 96 samples
# 96/96 [==============================] - 0s 5ms/step - loss: 0.0064 - categorical_accuracy: 0.9980
# Train on 97 samples
# 97/97 [==============================] - 0s 5ms/step - loss: 0.0064 - categorical_accuracy: 0.9980
# Train on 98 samples
# 98/98 [==============================] - 1s 5ms/step - loss: 0.0064 - categorical_accuracy: 0.9980
# Train on 99 samples
# 99/99 [==============================] - 1s 5ms/step - loss: 0.0064 - categorical_accuracy: 0.9980
# Train on 100 samples
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0064 - categorical_accuracy: 0.9980

# %%
#test
import numpy as np

X_test = data_grid(200,20)
Y_test = model.predict(X_test)
Y_test = np.argmax(Y_test, axis=1)

plt.figure(figsize=(8, 8))
plt.scatter(X_test[:, 0], X_test[:, 1], marker='o', c=Y_test*2, s=10)
plt.scatter(X[:, 0], X[:, 1], marker='o', c=Y, s=10)
plt.show()
plt.close()

# %% [markdown]
# plt.figure(figsize=(12, 12))
# for k in range(len(cluster_index)):
#     progress += 1
#     #print("Progress:{0}%".format(round((progress + 1) * 100 / len(cluster_index))), end="\r")
#     plt.scatter(X_test[cluster_index[k], 0], X_test[cluster_index[k], 1], marker='o',s=4, color=colors[data_activation_color[cluster_index[k]][0]]/255.0, linewidths=2)
# plt.margins(x=0.1, y=0.1)
# plt.show()
# plt.savefig('activation')

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.datasets import make_gaussian_quantiles
X1, Y1 = make_blobs(n_features=2, centers=10)
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1,
            s=25, edgecolor='k')
